# %%
# !pip install deepface

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2

demography = DeepFace.analyze("/content/1.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/1.jpg'))
# Out:
# Using TensorFlow backend.
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:02<?, ?it/s]
# Age:  23.719245455223813
# Gender:  Man
# Emotion:  neutral
# Race:  black

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/10.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/10.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  22.71410343143758
# Gender:  Man
# Emotion:  neutral
# Race:  black

# %% [markdown]
# #### Photo Number 16: No photo was found

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/17.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/17.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  36.719054814690494
# Gender:  Woman
# Emotion:  happy
# Race:  asian

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/19.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/19.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  36.861583303266045
# Gender:  Man
# Emotion:  neutral
# Race:  middle eastern

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/2.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/2.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  29.41933912096735
# Gender:  Man
# Emotion:  neutral
# Race:  black

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/20.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/20.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  31.059743183389322
# Gender:  Woman
# Emotion:  happy
# Race:  asian

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/21.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/21.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  32.354299868485334
# Gender:  Woman
# Emotion:  sad
# Race:  latino hispanic

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/22.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/22.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ...
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Age:  30.12925456868747
# Gender:  Man
# Emotion:  neutral
# Race:  black

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/23.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/23.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-10-0c3f8d9ac878> in <module>()
#       1 from deepface import DeepFace
# ----> 2 demography = DeepFace.analyze("/content/23.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#       3 #demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
#       4 print("Age: ", demography["age"])
#       5 print("Gender: ", demography["gender"])
#
# /usr/local/lib/python3.6/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection)
#     365                         age_model = models['age']
#     366                 else:
# --> 367                         age_model = Age.loadModel()
#     368
#     369         if 'gender' in actions:
#
# ...

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/233.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/233.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-11-5ae676782bb2> in <module>()
#       1 from deepface import DeepFace
# ----> 2 demography = DeepFace.analyze("/content/233.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#       3 #demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
#       4 print("Age: ", demography["age"])
#       5 print("Gender: ", demography["gender"])
#
# /usr/local/lib/python3.6/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection)
#     365                         age_model = models['age']
#     366                 else:
# --> 367                         age_model = Age.loadModel()
#     368
#     369         if 'gender' in actions:
#
# ...

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/24.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/24.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-00e7b142ce5e> in <module>()
#       1 from deepface import DeepFace
# ----> 2 demography = DeepFace.analyze("/content/24.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#       3 #demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
#       4 print("Age: ", demography["age"])
#       5 print("Gender: ", demography["gender"])
#
# /usr/local/lib/python3.6/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection)
#     358                         emotion_model = models['emotion']
#     359                 else:
# --> 360                         emotion_model = Emotion.loadModel()
#     361
#     362         if 'age' in actions:
#
# ...

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/25.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/25.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-99627dc94c62> in <module>()
#       1 from deepface import DeepFace
# ----> 2 demography = DeepFace.analyze("/content/25.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#       3 #demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
#       4 print("Age: ", demography["age"])
#       5 print("Gender: ", demography["gender"])
#
# /usr/local/lib/python3.6/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection)
#     358                         emotion_model = models['emotion']
#     359                 else:
# --> 360                         emotion_model = Emotion.loadModel()
#     361
#     362         if 'age' in actions:
#
# ...

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/26.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/26.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/27.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/27.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/28.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/28.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/29.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/29.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/3.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/3.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/30.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/30.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/31.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/31.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/32.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/32.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/33.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/33.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/34.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/34.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/35.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/35.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/36.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/36.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/37.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/37.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/38.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/38.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/39.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/39.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/4.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/4.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/40.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/40.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/41.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/41.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/42.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/42.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/5.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/5.jpg'))
# Out:
# Actions to do:  ['age', 'gender', 'race', 'emotion']
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-14-5dccbe6b4994> in <module>()
#       1 from deepface import DeepFace
# ----> 2 demography = DeepFace.analyze("/content/5.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#       3 #demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
#       4 print("Age: ", demography["age"])
#       5 print("Gender: ", demography["gender"])
#
# /usr/local/lib/python3.6/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection)
#     358                         emotion_model = models['emotion']
#     359                 else:
# --> 360                         emotion_model = Emotion.loadModel()
#     361
#     362         if 'age' in actions:
#
# ...

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/6.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/6.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/7.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/7.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/8.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/8.jpg'))

# %%
from deepface import DeepFace
demography = DeepFace.analyze("/content/9.jpg", actions = ['age', 'gender', 'race', 'emotion'])
#demographies = DeepFace.analyze(["img1.jpg", "img2.jpg", "img3.jpg"]) #analyzing multiple faces same time
print("Age: ", demography["age"])
print("Gender: ", demography["gender"])
print("Emotion: ", demography["dominant_emotion"])
print("Race: ", demography["dominant_race"])

plt.imshow(cv2.imread('/content/9.jpg'))
